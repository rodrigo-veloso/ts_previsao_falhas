# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_excel('manutencaoexcel.xlsx')

# %%
df
# Out:
#             Data Equipamento     Classe
# 0     2015-01-05      EQP140  CORRETIVA
# 1     2015-01-05       EQP12  CORRETIVA
# 2     2015-01-05       EQP13  CORRETIVA
# 3     2015-01-05       EQP28  CORRETIVA
# 4     2015-01-05       EQP15  CORRETIVA
# ...          ...         ...        ...
# 16090 2020-09-19       EQP08  CORRETIVA
# 16091 2020-09-20      EQP105  CORRETIVA
# 16092 2020-09-20       EQP28  CORRETIVA
# 16093 2020-09-20       EQP05  CORRETIVA
# 16094 2020-09-20       EQP02  CORRETIVA
#
# [16095 rows x 3 columns]

# %%
df = df[df['Classe']=='CORRETIVA']

# %%
df['Classe'] = 1
# Out:
# <ipython-input-141-3c47d8b4bebd>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Classe'] = 1

# %%
df.groupby('Equipamento').count().reset_index().sort_values('Classe',ascending=False).head(10)
# Out:
#    Equipamento  Data  Classe
# 2        EQP03  1586    1586
# 64       EQP19  1392    1392
# 5        EQP06  1358    1358
# 7        EQP08   979     979
# 3        EQP04   899     899
# 9        EQP10   892     892
# 73       EQP28   886     886
# 4        EQP05   808     808
# 1        EQP02   777     777
# 0        EQP01   756     756

# %%
ts = df[df['Equipamento'] == 'EQP03'].groupby('Data').count().reset_index().drop(["Equipamento"],axis=1)
plt.plot(ts['Data'],ts['Classe'])

# %%
ts = df[df['Equipamento'] == 'EQP19'].groupby('Data').count().reset_index().drop(["Equipamento"],axis=1)
plt.plot(ts['Data'],ts['Classe'])

# %%
ts = df[df['Equipamento'] == 'EQP06'].groupby('Data').count().reset_index().drop(["Equipamento"],axis=1)
plt.plot(ts['Data'],ts['Classe'])

# %%
ts = df[df['Equipamento'] == 'EQP28'].groupby('Data').count().reset_index().drop(["Equipamento"],axis=1)
plt.plot(ts['Data'],ts['Classe'])

# %%
df['Data'] = df['Data'].apply(lambda x: str(x))
df['Data'] = df['Data'].apply(lambda x: x[:8]+'15'+x[10:])
df['Data'] = df['Data'].astype("datetime64")
# Out:
# <ipython-input-125-579478db7457>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Data'] = df['Data'].apply(lambda x: str(x))
# <ipython-input-125-579478db7457>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Data'] = df['Data'].apply(lambda x: x[:8]+'15'+x[10:])
# <ipython-input-125-579478db7457>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Data'] = df['Data'].astype("datetime64")

# %%
ts = df[df['Equipamento'] == 'EQP03'].groupby('Data').count().reset_index().drop(["Equipamento"],axis=1)
plt.plot(ts['Data'],ts['Classe'])
ts.min()
# Out:
# Data      2015-01-15 00:00:00
# Classe                      1
# dtype: object

# %%
ts = df[df['Equipamento'] == 'EQP19'].groupby('Data').count().reset_index().drop(["Equipamento"],axis=1)
plt.plot(ts['Data'],ts['Classe'])
ts.min()
# Out:
# Data      2015-01-15 00:00:00
# Classe                      1
# dtype: object

# %%
ts = df[df['Equipamento'] == 'EQP06'].groupby('Data').count().reset_index().drop(["Equipamento"],axis=1)
plt.plot(ts['Data'],ts['Classe'])
ts.min()
# Out:
# Data      2015-01-15 00:00:00
# Classe                      1
# dtype: object

# %%
ts = df[df['Equipamento'] == 'EQP08'].groupby('Data').count().reset_index().drop(["Equipamento"],axis=1)
plt.plot(ts['Data'],ts['Classe'])
ts.min()
# Out:
# Data      2015-01-15 00:00:00
# Classe                      1
# dtype: object

# %%
ts = df[df['Equipamento'] == 'EQP04'].groupby('Data').count().reset_index().drop(["Equipamento"],axis=1)
plt.plot(ts['Data'],ts['Classe'])
ts.min()
# Out:
# Data      2015-01-15 00:00:00
# Classe                      1
# dtype: object

# %%
ts = df[df['Equipamento'] == 'EQP10'].groupby('Data').count().reset_index().drop(["Equipamento"],axis=1)
plt.plot(ts['Data'],ts['Classe'])
ts.min()
# Out:
# Data      2015-01-15 00:00:00
# Classe                      1
# dtype: object

# %%
ts = df[df['Equipamento'] == 'EQP28'].groupby('Data').count().reset_index().drop(["Equipamento"],axis=1)
plt.plot(ts['Data'],ts['Classe'])
ts.min()
# Out:
# Data      2015-01-15 00:00:00
# Classe                      1
# dtype: object

# %%
ts = df[df['Equipamento'] == 'EQP05'].groupby('Data').count().reset_index().drop(["Equipamento"],axis=1)
plt.plot(ts['Data'],ts['Classe'])
ts.min()
# Out:
# Data      2015-01-15 00:00:00
# Classe                      1
# dtype: object

# %%
ts = df[df['Equipamento'] == 'EQP02'].groupby('Data').count().reset_index().drop(["Equipamento"],axis=1)
plt.plot(ts['Data'],ts['Classe'])
ts.min()
# Out:
# Data      2015-01-15 00:00:00
# Classe                      1
# dtype: object

# %%
ts = df[df['Equipamento'] == 'EQP01'].groupby('Data').count().reset_index().drop(["Equipamento"],axis=1)
plt.plot(ts['Data'],ts['Classe'])
ts.min()
# Out:
# Data      2015-01-15 00:00:00
# Classe                      1
# dtype: object

# %%
ts.describe()
# Out:
#           Classe
# count  68.000000
# mean   11.117647
# std    12.299168
# min     1.000000
# 25%     1.750000
# 50%     6.500000
# 75%    18.000000
# max    57.000000

# %%
for equipamento in df.groupby('Equipamento').count().reset_index().sort_values('Classe',ascending=False).head(15)['Equipamento'].iloc:
    print(equipamento)
# Out:
# EQP03
# EQP19
# EQP06
# EQP08
# EQP04
# EQP10
# EQP28
# EQP05
# EQP02
# EQP01
# EQP07
# EQP13
# EQP24
# EQP15
# EQP12
